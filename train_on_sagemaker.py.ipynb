# %%
# !pip install torch torchvision torchaudio --index-url https://download.pytorch.org/whl/cu118
# !pip install boto3 sagemaker
# !git clone https://github.com/ultralytics/yolov5.git
# %cd yolov5
# !pip install -r requirements.txt
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu118
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 23.2/23.2 MB 123.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 875.6/875.6 kB 98.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.1/13.1 MB 130.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 663.9/663.9 MB 39.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 417.9/417.9 MB 44.6 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 149.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 58.1/58.1 MB 88.8 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 128.2/128.2 MB 125.4 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 204.1/204.1 MB 135.9 MB/s eta 0:00:0000:0100:01
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 147.8/147.8 MB 196.5 MB/s eta 0:00:0000:0100:01
# ...

# %%
import os
print(os.getcwd())  # This prints the current working directory
# Out:
# /home/ec2-user/SageMaker/yolov5

# %%
# !python train.py --img 640 --batch 16 --epochs 100 --data dataset2/data.yaml --weights yolov5s.pt --device 0
# !python train.py --img 640 --batch 16 --epochs 100 --data dataset2/data.yaml --weights yolov5s.pt --device 0 > train.log 2>&1
# !python train.py --img 640 --batch 16 --epochs 100 --data indian_coin/data.yaml --weights yolov5s.pt --device 0 > train_indian_coin.log 2>&1

# %%
import torch
print("GPU Available:", torch.cuda.is_available())
print("GPU Name:", torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")
print("CUDA Version:", torch.version.cuda if torch.cuda.is_available() else "N/A")
# Out:
# GPU Available: True
# GPU Name: NVIDIA A10G
# CUDA Version: 11.8

# %%
# !aws s3 cp --recursive s3://sagemaker-ap-south-1-017820699325/DataSet/ /home/ec2-user/SageMaker/yolov5/dataset/ 
# !aws s3 cp --recursive s3://sagemaker-ap-south-1-017820699325/dataset/ /home/ec2-user/SageMaker/yolov5/dataset2/
# !aws s3 cp --recursive s3://sagemaker-ap-south-1-017820699325/indian_coin/ /home/ec2-user/SageMaker/yolov5/indian_coin/
# Out:
# download: s3://sagemaker-ap-south-1-017820699325/indian_coin/data.yaml to indian_coin/data.yaml
# download: s3://sagemaker-ap-south-1-017820699325/indian_coin/test/images/104_jpg.rf.4e19715ea896ab9ce5f32c9c3cb0adca.jpg to indian_coin/test/images/104_jpg.rf.4e19715ea896ab9ce5f32c9c3cb0adca.jpg
# download: s3://sagemaker-ap-south-1-017820699325/indian_coin/test/images/101_jpg.rf.785612c2d3c2ea53be75071bd121cd15.jpg to indian_coin/test/images/101_jpg.rf.785612c2d3c2ea53be75071bd121cd15.jpg
# download: s3://sagemaker-ap-south-1-017820699325/indian_coin/test/images/0_jpg.rf.f1791b1619cacac78d8b707c2b728bd4.jpg to indian_coin/test/images/0_jpg.rf.f1791b1619cacac78d8b707c2b728bd4.jpg
# download: s3://sagemaker-ap-south-1-017820699325/indian_coin/test/images/104_jpg.rf.da7eb90fa1454b9767f0d34d93a9b089.jpg to indian_coin/test/images/104_jpg.rf.da7eb90fa1454b9767f0d34d93a9b089.jpg
# ...

# %%
import os
print(os.path.exists("indian_coin/data.yaml"))
# Out:
# True

# %%
# !python val.py --weights runs/train/exp/weights/best.pt --data indian_coin/data.yaml --img 640 --task val
# Out:
# val: data=indian_coin/data.yaml, weights=['runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-411-gf4d8a84c Python-3.10.16 torch-2.6.0+cu118 CUDA:0 (NVIDIA A10G, 22503MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7029004 parameters, 0 gradients, 15.8 GFLOPs
# val: Scanning /home/ec2-user/SageMaker/yolov5/indian_coin/val/labels.cache... 47
#                  Class     Images  Instances          P          R      mAP50
#                    all        474       1836      0.998      0.996      0.995      0.943
#                   10RS        474        195      0.999      0.995      0.995      0.943
#                    1RS        474        320      0.997      0.994      0.995      0.931
# ...

# %%
# !python val.py --weights runs/train/exp/weights/best.pt --data indian_coin/data.yaml --img 640 --task test
# Out:
# val: data=indian_coin/data.yaml, weights=['runs/train/exp/weights/best.pt'], batch_size=32, imgsz=640, conf_thres=0.001, iou_thres=0.6, max_det=300, task=test, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=False, dnn=False
# YOLOv5 🚀 v7.0-411-gf4d8a84c Python-3.10.16 torch-2.6.0+cu118 CUDA:0 (NVIDIA A10G, 22503MiB)
#
# Fusing layers...
# Model summary: 157 layers, 7029004 parameters, 0 gradients, 15.8 GFLOPs
# test: Scanning /home/ec2-user/SageMaker/yolov5/indian_coin/test/labels... 495 im
# test: New cache created: /home/ec2-user/SageMaker/yolov5/indian_coin/test/labels.cache
#                  Class     Images  Instances          P          R      mAP50
#                    all        495       1965      0.997      0.998      0.995      0.943
#                   10RS        495        195      0.999          1      0.995      0.949
# ...
